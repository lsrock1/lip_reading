# %%
from models import LipRead

# %%
from thop import profile

# %%
flops, params = profile(LipRead({
    'model': {
        'attention': False,
        'coord': True,
        'temporal': True,
        'input_dim': 256,
        'num_class': 500,
        'num_lstm': 2,
        'attention_dropout': 0.5,
        'hidden_dim': 256
        
    },
    'input': {
        'landmark': True,
        'landmark_seperate': False,
        'batch_size': 16
    }
}), input_size=(1, 29, 1, 112, 112))
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/anaconda3/envs/pytorch/lib/python3.6/logging/__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "/anaconda3/envs/pytorch/lib/python3.6/logging/__init__.py", line 840, in format
#     return fmt.format(record)
#   File "/anaconda3/envs/pytorch/lib/python3.6/logging/__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "/anaconda3/envs/pytorch/lib/python3.6/logging/__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/anaconda3/envs/pytorch/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/envs/pytorch/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
# ...
